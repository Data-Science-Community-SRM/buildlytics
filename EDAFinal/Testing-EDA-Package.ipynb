# %%
import pandas as pd
from EDA import EDA

# %%
data=pd.read_csv("../data/star-prediction/stars.csv")
data.head()
# Out:
#    Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0             3068          0.002400        0.1700                   16.12
# 1             3042          0.000500        0.1542                   16.60
# 2             2600          0.000300        0.1020                   18.70
# 3             2800          0.000200        0.1600                   16.65
# 4             1939          0.000138        0.1030                   20.06
#
#    Star type Star color Spectral Class
# 0          0        Red              M
# 1          0        Red              M
# 2          0        Red              M
# 3          0        Red              M
# 4          0        Red              M

# %%
eda=EDA()
eda.HeatMaps(data)
# Out:
# <AxesSubplot:>

# %%
eda.PairPlot(data)

# %%
eda.viewtop(data)
# Out:
#    Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0             3068          0.002400        0.1700                   16.12
# 1             3042          0.000500        0.1542                   16.60
# 2             2600          0.000300        0.1020                   18.70
# 3             2800          0.000200        0.1600                   16.65
# 4             1939          0.000138        0.1030                   20.06
#
#    Star type Star color Spectral Class
# 0          0        Red              M
# 1          0        Red              M
# 2          0        Red              M
# 3          0        Red              M
# 4          0        Red              M

# %%
eda.viewbottom(data)
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 235            38940          374830.0        1356.0                   -9.93
# 236            30839          834042.0        1194.0                  -10.63
# 237             8829          537493.0        1423.0                  -10.73
# 238             9235          404940.0        1112.0                  -11.23
# 239            37882          294903.0        1783.0                   -7.80
#
#      Star type Star color Spectral Class
# 235          5       Blue              O
# 236          5       Blue              O
# 237          5      White              A
# 238          5      White              A
# 239          5       Blue              O

# %%
eda.viewnull(data)
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0               True              True          True                    True
# 1               True              True          True                    True
# 2               True              True          True                    True
# 3               True              True          True                    True
# 4               True              True          True                    True
# ..               ...               ...           ...                     ...
# 235             True              True          True                    True
# 236             True              True          True                    True
# 237             True              True          True                    True
# 238             True              True          True                    True
# 239             True              True          True                    True
#
#      Star type  Star color  Spectral Class
# ...

# %%
eda.viewstats(data)
# Out:
# (Temperature (K)            10497.462500
#  Luminosity(L/Lo)          107188.361635
#  Radius(R/Ro)                 237.157781
#  Absolute magnitude(Mv)         4.382396
#  Star type                      2.500000
#  dtype: float64,
#  Temperature (K)           5776.0000
#  Luminosity(L/Lo)             0.0705
#  Radius(R/Ro)                 0.7625
#  Absolute magnitude(Mv)       8.3130
#  Star type                    2.5000
#  dtype: float64,
#     Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
#  0           3600.0          200000.0          0.11                   12.23
#  1              NaN               NaN          0.24                     NaN
#  2              NaN               NaN         36.00                     NaN
#  3              NaN               NaN       1324.00                     NaN
#  4              NaN               NaN           NaN                     NaN
#  5              NaN               NaN           NaN                     NaN
#
# ...

# %%
eda.ScatterGrp(data,"Temperature (K)","Radius(R/Ro)","Temperature (K)")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-0ce5a5b2ef1f> in <module>
# ----> 1 eda.ScatterGrp(data,"Temperature (K)","Radius(R/Ro)","Temperature (K)")
#
# ~/Notebooks/DScommunity/EDA.py in ScatterGrp(self, data, colx, coly, cols, color, ratio, font, save, save_name)
#      58         # Prepare the aspect of the plot
#      59         plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = False
# ---> 60         plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = True
#      61         plt.rcParams['font.sans-serif']=font
#      62         plt.rcParams['xtick.color']=color[-1]
#
# AttributeError: 'EDA' object has no attribute 'self'
